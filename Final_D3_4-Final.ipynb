# %%
import numpy as np
seed = 46
np.random.seed(seed)

from scipy import stats
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.preprocessing import MinMaxScaler, label_binarize
from sklearn.metrics import (
    balanced_accuracy_score, f1_score, confusion_matrix,
    roc_auc_score
)
from sklearn.model_selection import StratifiedKFold
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from imblearn.over_sampling import RandomOverSampler
from sklearn.impute import SimpleImputer
from collections import Counter
from prettytable import PrettyTable
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def remove_outliers(data, column):
    np.random.seed(seed)
    z_scores = np.abs(stats.zscore(data[column]))
    threshold = 2  # Adjust this threshold as needed
    data_without_outliers = data[(z_scores < threshold)]
    return data_without_outliers

def select_features(X_train, y_train, method, feature, X,
                    response_variable):
    np.random.seed(seed)
    fs = SelectKBest(score_func=method, k=feature)
    selected = fs.fit_transform(X_train, y_train)
    idx = fs.get_support(indices=True)
    columns = X.iloc[:, idx].columns
    
    fig = plt.figure(figsize=(5,3))
    pd.Series(fs.scores_[idx], index=columns).nlargest(
        feature).plot(kind='barh', color='gray').invert_yaxis()
    # Increase the text size
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.xlabel('Score', fontsize=20)
    plt.ylabel('Features', fontsize=20)
    plt.show()
    name = '../Results/' + response_variable + str(feature) + '.jpeg'
    fig.savefig(name, dpi=300, bbox_inches='tight')
    
    return idx

def select_model():
    np.random.seed(seed)
    lda = LinearDiscriminantAnalysis()
    knn = KNeighborsClassifier(n_neighbors=4)
    mlp = MLPClassifier(hidden_layer_sizes=(80, 80), activation='tanh', max_iter=5000)
    return lda, knn, mlp

def split_train_test(X, y, feature_options, outcome, folds):
    np.random.seed(seed)
    cols = X.columns
    tables = []
    kfold = StratifiedKFold(n_splits=folds, shuffle=True)
    selected_features = None

    for i, (train, test) in enumerate(kfold.split(X, y)):
        X_train, y_train, X_test, y_test = X.iloc[train], y.iloc[train], X.iloc[test], y.iloc[test]
        
        org = X_train
        
        scaler = MinMaxScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        ros = RandomOverSampler(random_state=seed)
        X_train, y_train = ros.fit_resample(X_train, y_train)
        print(np.shape(X_train))
        
        imp = SimpleImputer(strategy="median")
        X_train = pd.DataFrame(imp.fit_transform(X_train))
        X_test = pd.DataFrame(imp.transform(X_test))
        
        if i == 0:
            selected_features = select_features(X_train, y_train, mutual_info_classif,
                                                feature, org, outcome)
            
        X_train_selected = X_train.iloc[:, selected_features]
        X_test_selected = X_test.iloc[:, selected_features]
        
        table = main(X_train_selected, X_test_selected, y_train, y_test, feature, cols, outcome)
        tables.extend(table)

    return pd.DataFrame(tables)


def main(X_train, X_test, y_train, y_test, feature, cols, outcome):
    models = select_model()
    results = []
    threshold = 0.55  # Define the threshold value

    for model in models:

        # Training
        model.fit(X_train, y_train)
        y_pred_train = model.predict_proba(X_train)[:, 1]  # Use probability predictions for positive class
        y_binary = np.where(y_pred_train > threshold, 1, 0)  # Convert to binary form
        train_score = balanced_accuracy_score(y_train, y_binary)

        # Testing
        y_pred_proba = model.predict_proba(X_test)
        if len(np.unique(y_train)) == 2:  # Binary classification case
            y_pred = np.where(y_pred_proba[:, 1] >= threshold, 1, 0)  # Adjust threshold as needed
            accuracy = balanced_accuracy_score(y_test, y_pred)
            roc_auc = roc_auc_score(y_test, y_pred_proba[:, 1])
            f1 = f1_score(y_test, y_pred, average='weighted')
        else:  # Multiclass classification case
            y_pred_proba_normalized = y_pred_proba / np.sum(y_pred_proba, axis=1, keepdims=True)
            y_pred = np.argmax(y_pred_proba_normalized, axis=1)  # Convert probabilities to class labels
            accuracy = balanced_accuracy_score(y_test, y_pred)
            roc_auc = roc_auc_score(y_test, y_pred_proba_normalized, multi_class='ovo')
            f1 = f1_score(y_test, y_pred, average='macro')  # or 'micro' based on preference

        #f1 = f1_score(y_test, y_pred, average='weighted')
        #cm = confusion_matrix(y_test, y_pred)
        #print(cm)
        
        # Saving results
        results.append({
            'Response': outcome,
            'Features': feature,
            'Train_Bal_Accuracy': train_score,
            'Model': model.__class__.__name__,
            'Balanced Accuracy': accuracy,
            'F1 Score': f1,
            'ROC AUC': roc_auc
        })

    return results

def create_response2(y):
    y_new = np.where((y['d100agvhd24'] == 1) & (y['d100agvhd34'] == 1), 1, 0)
    return y_new


def create_response3(y):
    y_new = np.where((y['d100agvhd24'] == 0) & (y['d100agvhd34'] == 0), 0,
                     np.where((y['d100agvhd24'] == 1) & (y['d100agvhd34'] == 1), 2, 1))
    return y_new


results_table = []
results = []

if __name__ == '__main__':
    X_cols = ['yeartx', 'age', 'gvhdgpmod', 'karnofcat', 'intdxtx', 'donorgpa', 'atgyndos', 'drcmvpr_2',
              'condescrpmod', 'olkstaprgp', 'coorgscoremod']

    Y_cols = ['agvhd', 'd100agvhd24', 'd100agvhd34']
    response_options = ['d100agvhd24', 'response_0to2_vs_3to4', 'response_0and1_vs_2_vs_3and4']

    response_feature_options = {
    'd100agvhd24': [5, 6, 8],
    'response_0to2_vs_3to4': [5, 6, 9],
    'response_0and1_vs_2_vs_3and4': [5, 6, 7]
    }
    
    Path_datafile = '../Data/ck1901_public_datafile.sas7bdat'

    raw_data = pd.read_sas(Path_datafile, format='sas7bdat')

    column_to_convert = ['gvhdgpmod', 'karnofcat', 'donorgpa', 'atgyndos', 'drcmvpr_2', 'condescrpmod',
                         'olkstaprgp', 'coorgscoremod']
    raw_data[column_to_convert] = raw_data[column_to_convert].astype('category')
    data = raw_data.copy()
    
    print('Raw data', np.shape(data))
    
    data.replace(99, np.nan, inplace=True)
    data.dropna(how='any', subset=Y_cols, inplace=True)
    
    print('Shape after dropping missing response', np.shape(data))
    
    # Apply response variable creation to the data
    data['response_0to2_vs_3to4'] = create_response2(data)
    data['response_0and1_vs_2_vs_3and4'] = create_response3(data)
    
    print('shape after adding two new response', np.shape(data))
    
    # Remove outliers from the numeric columns
    numeric_columns = ['yeartx', 'age', 'intdxtx']
    for column in numeric_columns:
        data = remove_outliers(data, column)
        
    print('Shape of the data after dropping outliers', np.shape(data))
    
    Y = data[response_options].copy()
    X = data[X_cols].copy()
    splits = 4

    for response_option in response_options:
        print("Response Variable: ", response_option)
        print("=" * 50)

        feature_options_response = response_feature_options.get(
            response_option, [])
        print(Counter(Y[response_option]))

        for feature in feature_options_response:
            result = split_train_test(X, Y[response_option], feature, response_option, splits)
            
            # Group the DataFrame by Model and calculate the average for each metric
            avg_results = result.groupby(['Model', 'Response']).mean()
            
            # Create a pretty table and add the columns
            table = PrettyTable()
            table.field_names = ['Model'] + list(avg_results.columns)

            # Add rows to the table
            for index, row in avg_results.iterrows():
                model = index
                table.add_row([model] + 
                              [f'{value:.2f}' for value in row])

            # Print the table
            print(table)
            
            # save for box
            results.append(result)
    
    results_table = pd.concat(results, ignore_index=True)

    # Create subplots for each response type
    fig, axes = plt.subplots(1, 3, figsize=(15, 6), sharey=True)
    
    # Plot box plots for agvhd
    sns.boxplot(data=results_table[
                results_table['Response'] == 'd100agvhd24'],
                y='Balanced Accuracy',
                x='Features', hue='Model', ax=axes[0])
    plt.legend(fontsize='12')
    axes[0].set_title('Response 0 to 1 vs 2 to 4', fontsize=20)
    axes[0].tick_params(axis='both', labelsize=20)
    axes[0].set_xlabel("Features",fontsize=20)
    axes[0].set_ylabel("Balanced Accuracy",fontsize=20)

    # Plot box plots for response_0to2_vs_3to4
    sns.boxplot(data=results_table[
                results_table['Response'] == 'response_0to2_vs_3to4'],
                y='Balanced Accuracy',
                x='Features', hue='Model', ax=axes[1])
    axes[1].set_title('Response 0 to 2 vs 3 to 4', fontsize=20)
    axes[1].tick_params(axis='both', labelsize=20)
    axes[1].set_xlabel("Features",fontsize=20)

    # Plot box plots for response_0and1_vs_2_vs_3and4
    sns.boxplot(data=results_table[
                results_table['Response'] == 
                'response_0and1_vs_2_vs_3and4'],
                y='Balanced Accuracy',
                x='Features', hue='Model', ax=axes[2])
    axes[2].set_title('Response 0 and 1 vs 2 vs 3 and 4', fontsize=20)
    axes[2].tick_params(axis='both', labelsize=20)
    axes[2].set_xlabel("Features",fontsize=20)
    
    plt.tight_layout()
    plt.show()
    fig.savefig('../Results/1.jpeg', dpi=1200, bbox_inches='tight')
# Out:
# Raw data (241, 37)
# Shape after dropping missing response (216, 37)
# shape after adding two new response (216, 39)
# Shape of the data after dropping outliers (197, 39)
# Response Variable:  d100agvhd24
# ==================================================
# Counter({0.0: 114, 1.0: 83})
# (170, 11)
# [[25  4]
#  [13  8]]
# [[21  8]
#  [15  6]]
# [[23  6]
#  [13  8]]
# (170, 11)
# [[17 12]
#  [14  6]]
# [[20  9]
#  [13  7]]
# [[17 12]
#  [15  5]]
# (172, 11)
# [[21  7]
#  [15  6]]
# [[21  7]
#  [12  9]]
# [[21  7]
#  [16  5]]
# (172, 11)
# [[23  5]
#  [11 10]]
# [[21  7]
#  [12  9]]
# [[22  6]
#  [11 10]]
# +-----------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |                     Model                     | Features | Train_Bal_Accuracy | Balanced Accuracy | F1 Score | ROC AUC |
# +-----------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |    ('KNeighborsClassifier', 'd100agvhd24')    |   5.00   |        0.73        |        0.55       |   0.57   |   0.56  |
# | ('LinearDiscriminantAnalysis', 'd100agvhd24') |   5.00   |        0.58        |        0.56       |   0.57   |   0.59  |
# |        ('MLPClassifier', 'd100agvhd24')       |   5.00   |        0.59        |        0.53       |   0.55   |   0.59  |
# +-----------------------------------------------+----------+--------------------+-------------------+----------+---------+
# (170, 11)
# [[25  4]
#  [13  8]]
# [[20  9]
#  [15  6]]
# [[22  7]
#  [12  9]]
# (170, 11)
# [[17 12]
#  [15  5]]
# [[20  9]
#  [13  7]]
# [[17 12]
#  [14  6]]
# (172, 11)
# [[22  6]
#  [15  6]]
# [[21  7]
#  [13  8]]
# [[22  6]
#  [13  8]]
# (172, 11)
# [[23  5]
#  [11 10]]
# [[21  7]
#  [13  8]]
# [[23  5]
#  [11 10]]
# +-----------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |                     Model                     | Features | Train_Bal_Accuracy | Balanced Accuracy | F1 Score | ROC AUC |
# +-----------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |    ('KNeighborsClassifier', 'd100agvhd24')    |   6.00   |        0.73        |        0.53       |   0.55   |   0.56  |
# | ('LinearDiscriminantAnalysis', 'd100agvhd24') |   6.00   |        0.59        |        0.56       |   0.57   |   0.58  |
# |        ('MLPClassifier', 'd100agvhd24')       |   6.00   |        0.58        |        0.57       |   0.58   |   0.58  |
# +-----------------------------------------------+----------+--------------------+-------------------+----------+---------+
# (170, 11)
# [[24  5]
#  [13  8]]
# [[20  9]
#  [13  8]]
# [[17 12]
#  [12  9]]
# (170, 11)
# [[17 12]
#  [12  8]]
# [[20  9]
#  [13  7]]
# [[15 14]
#  [ 7 13]]
# (172, 11)
# [[22  6]
#  [15  6]]
# [[20  8]
#  [14  7]]
# [[21  7]
#  [15  6]]
# (172, 11)
# [[23  5]
#  [10 11]]
# [[15 13]
#  [11 10]]
# [[20  8]
#  [16  5]]
# +-----------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |                     Model                     | Features | Train_Bal_Accuracy | Balanced Accuracy | F1 Score | ROC AUC |
# +-----------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |    ('KNeighborsClassifier', 'd100agvhd24')    |   8.00   |        0.75        |        0.52       |   0.53   |   0.57  |
# | ('LinearDiscriminantAnalysis', 'd100agvhd24') |   8.00   |        0.61        |        0.58       |   0.59   |   0.59  |
# |        ('MLPClassifier', 'd100agvhd24')       |   8.00   |        0.91        |        0.52       |   0.53   |   0.55  |
# +-----------------------------------------------+----------+--------------------+-------------------+----------+---------+
# Response Variable:  response_0to2_vs_3to4
# ==================================================
# Counter({0: 172, 1: 25})
# (258, 11)
# [[33 10]
#  [ 5  2]]
# [[36  7]
#  [ 6  1]]
# [[32 11]
#  [ 5  2]]
# (258, 11)
# [[32 11]
#  [ 3  3]]
# [[35  8]
#  [ 5  1]]
# [[32 11]
#  [ 3  3]]
# (258, 11)
# [[35  8]
#  [ 3  3]]
# [[36  7]
#  [ 4  2]]
# [[36  7]
#  [ 3  3]]
# (258, 11)
# [[32 11]
#  [ 5  1]]
# [[35  8]
#  [ 3  3]]
# [[32 11]
#  [ 5  1]]
# +---------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |                          Model                          | Features | Train_Bal_Accuracy | Balanced Accuracy | F1 Score | ROC AUC |
# +---------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |    ('KNeighborsClassifier', 'response_0to2_vs_3to4')    |   5.00   |        0.95        |        0.56       |   0.77   |   0.60  |
# | ('LinearDiscriminantAnalysis', 'response_0to2_vs_3to4') |   5.00   |        0.69        |        0.57       |   0.75   |   0.60  |
# |        ('MLPClassifier', 'response_0to2_vs_3to4')       |   5.00   |        0.67        |        0.57       |   0.75   |   0.59  |
# +---------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# (258, 11)
# [[32 11]
#  [ 5  2]]
# [[34  9]
#  [ 4  3]]
# [[33 10]
#  [ 5  2]]
# (258, 11)
# [[30 13]
#  [ 2  4]]
# [[28 15]
#  [ 5  1]]
# [[36  7]
#  [ 4  2]]
# (258, 11)
# [[32 11]
#  [ 3  3]]
# [[33 10]
#  [ 4  2]]
# [[38  5]
#  [ 5  1]]
# (258, 11)
# [[32 11]
#  [ 5  1]]
# [[31 12]
#  [ 4  2]]
# [[32 11]
#  [ 5  1]]
# +---------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |                          Model                          | Features | Train_Bal_Accuracy | Balanced Accuracy | F1 Score | ROC AUC |
# +---------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |    ('KNeighborsClassifier', 'response_0to2_vs_3to4')    |   6.00   |        0.93        |        0.52       |   0.72   |   0.60  |
# | ('LinearDiscriminantAnalysis', 'response_0to2_vs_3to4') |   6.00   |        0.70        |        0.57       |   0.73   |   0.60  |
# |        ('MLPClassifier', 'response_0to2_vs_3to4')       |   6.00   |        0.85        |        0.52       |   0.76   |   0.55  |
# +---------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# (258, 11)
# [[33 10]
#  [ 6  1]]
# [[32 11]
#  [ 5  2]]
# [[39  4]
#  [ 7  0]]
# (258, 11)
# [[31 12]
#  [ 2  4]]
# [[35  8]
#  [ 4  2]]
# [[37  6]
#  [ 6  0]]
# (258, 11)
# [[35  8]
#  [ 3  3]]
# [[31 12]
#  [ 5  1]]
# [[41  2]
#  [ 5  1]]
# (258, 11)
# [[30 13]
#  [ 4  2]]
# [[32 11]
#  [ 4  2]]
# [[37  6]
#  [ 5  1]]
# +---------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |                          Model                          | Features | Train_Bal_Accuracy | Balanced Accuracy | F1 Score | ROC AUC |
# +---------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |    ('KNeighborsClassifier', 'response_0to2_vs_3to4')    |   9.00   |        0.94        |        0.52       |   0.73   |   0.53  |
# | ('LinearDiscriminantAnalysis', 'response_0to2_vs_3to4') |   9.00   |        0.71        |        0.58       |   0.74   |   0.58  |
# |        ('MLPClassifier', 'response_0to2_vs_3to4')       |   9.00   |        1.00        |        0.49       |   0.78   |   0.50  |
# +---------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# Response Variable:  response_0and1_vs_2_vs_3and4
# ==================================================
# Counter({0: 114, 1: 58, 2: 25})
# (255, 11)
# [[18  6  5]
#  [ 7  4  4]
#  [ 2  3  1]]
# [[14  8  7]
#  [ 8  2  5]
#  [ 2  2  2]]
# [[18  6  5]
#  [ 8  3  4]
#  [ 5  0  1]]
# (255, 11)
# [[12  6 11]
#  [ 7  3  4]
#  [ 2  2  2]]
# [[16  9  4]
#  [ 8  3  3]
#  [ 2  2  2]]
# [[12  6 11]
#  [ 7  3  4]
#  [ 2  2  2]]
# (258, 11)
# [[21  2  5]
#  [ 7  4  3]
#  [ 4  2  1]]
# [[16  9  3]
#  [ 5  7  2]
#  [ 3  2  2]]
# [[21  3  4]
#  [ 6  5  3]
#  [ 4  2  1]]
# (258, 11)
# [[17  5  6]
#  [ 8  1  6]
#  [ 1  1  4]]
# [[13 10  5]
#  [ 9  4  2]
#  [ 3  2  1]]
# [[16  6  6]
#  [ 7  3  5]
#  [ 0  3  3]]
# +----------------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |                             Model                              | Features | Train_Bal_Accuracy | Balanced Accuracy | F1 Score | ROC AUC |
# +----------------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |    ('KNeighborsClassifier', 'response_0and1_vs_2_vs_3and4')    |   5.00   |        0.51        |        0.36       |   0.35   |   0.50  |
# | ('LinearDiscriminantAnalysis', 'response_0and1_vs_2_vs_3and4') |   5.00   |        0.34        |        0.38       |   0.35   |   0.54  |
# |       ('MLPClassifier', 'response_0and1_vs_2_vs_3and4')        |   5.00   |        0.34        |        0.37       |   0.36   |   0.55  |
# +----------------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# (255, 11)
# [[12  8  9]
#  [ 6  4  5]
#  [ 1  3  2]]
# [[16  5  8]
#  [10  1  4]
#  [ 2  3  1]]
# [[16  3 10]
#  [ 6  3  6]
#  [ 4  0  2]]
# (255, 11)
# [[11  8 10]
#  [ 5  5  4]
#  [ 3  1  2]]
# [[14  7  8]
#  [ 6  5  3]
#  [ 2  2  2]]
# [[14  8  7]
#  [ 6  4  4]
#  [ 3  1  2]]
# (258, 11)
# [[20  3  5]
#  [ 5  6  3]
#  [ 4  2  1]]
# [[17  7  4]
#  [ 6  6  2]
#  [ 4  2  1]]
# [[15  7  6]
#  [ 4  8  2]
#  [ 3  3  1]]
# (258, 11)
# [[15  5  8]
#  [ 7  4  4]
#  [ 0  2  4]]
# [[14  6  8]
#  [ 7  6  2]
#  [ 4  1  1]]
# [[20  2  6]
#  [ 7  6  2]
#  [ 0  1  5]]
# +----------------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |                             Model                              | Features | Train_Bal_Accuracy | Balanced Accuracy | F1 Score | ROC AUC |
# +----------------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |    ('KNeighborsClassifier', 'response_0and1_vs_2_vs_3and4')    |   6.00   |        0.52        |        0.35       |   0.34   |   0.49  |
# | ('LinearDiscriminantAnalysis', 'response_0and1_vs_2_vs_3and4') |   6.00   |        0.34        |        0.40       |   0.38   |   0.56  |
# |       ('MLPClassifier', 'response_0and1_vs_2_vs_3and4')        |   6.00   |        0.34        |        0.45       |   0.42   |   0.56  |
# +----------------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# (255, 11)
# [[12  7 10]
#  [ 6  4  5]
#  [ 1  3  2]]
# [[17  5  7]
#  [ 9  1  5]
#  [ 3  1  2]]
# [[14  7  8]
#  [ 6  4  5]
#  [ 2  2  2]]
# (255, 11)
# [[12  7 10]
#  [ 4  6  4]
#  [ 3  1  2]]
# [[12 10  7]
#  [ 6  7  1]
#  [ 2  2  2]]
# [[12  7 10]
#  [ 4  5  5]
#  [ 2  2  2]]
# (258, 11)
# [[15  8  5]
#  [ 6  6  2]
#  [ 4  2  1]]
# [[11 10  7]
#  [ 7  4  3]
#  [ 3  4  0]]
# [[13  9  6]
#  [ 5  6  3]
#  [ 4  2  1]]
# (258, 11)
# [[16  4  8]
#  [ 7  4  4]
#  [ 0  1  5]]
# [[13  6  9]
#  [ 8  5  2]
#  [ 4  1  1]]
# [[15  6  7]
#  [ 5  6  4]
#  [ 0  2  4]]
# +----------------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |                             Model                              | Features | Train_Bal_Accuracy | Balanced Accuracy | F1 Score | ROC AUC |
# +----------------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# |    ('KNeighborsClassifier', 'response_0and1_vs_2_vs_3and4')    |   7.00   |        0.52        |        0.32       |   0.31   |   0.52  |
# | ('LinearDiscriminantAnalysis', 'response_0and1_vs_2_vs_3and4') |   7.00   |        0.34        |        0.41       |   0.38   |   0.55  |
# |       ('MLPClassifier', 'response_0and1_vs_2_vs_3and4')        |   7.00   |        0.35        |        0.40       |   0.38   |   0.55  |
# +----------------------------------------------------------------+----------+--------------------+-------------------+----------+---------+
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
